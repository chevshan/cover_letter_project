# %%
import os
import json
from dotenv import load_dotenv
from linkedin_api import Linkedin

load_dotenv()

api = Linkedin(username=str(os.getenv("EMAIL_LOGIN")), password=str(os.getenv("EMAIL_PASSWORD")))

# %%
url = "https://www.linkedin.com/jobs/view/4288878222"
job_id = "4288878222"

job = api.get_job(job_id)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 4
#       1 url = "https://www.linkedin.com/jobs/view/4288878222"
#       2 job_id = "4288878222"
# ----> 4 job = api.get_job(job_id)
#
# File ~/anaconda3/envs/pet_project/lib/python3.10/site-packages/linkedin_api/linkedin.py:1691, in Linkedin.get_job(self, job_id)
#    1688 data = res.json()
#    1690 if data and "status" in data and data["status"] != 200:
# -> 1691     self.logger.info("request failed: {}".format(data["message"]))
#    1692     return {}
#    1694 return data
#
# KeyError: 'message'

# %%
job
# Out:
# {'dashEntityUrn': 'urn:li:fsd_jobPosting:4332807390',
#  'companyDetails': {'com.linkedin.voyager.deco.jobs.web.shared.WebCompactJobPostingCompany': {'companyResolutionResult': {'entityUrn': 'urn:li:fs_normalized_company:11523043',
#     'name': 'Naveksoft',
#     'logo': {'image': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 200,
#          'fileIdentifyingUrlPathSegment': '200_200/company-logo_200_200/0/1633002358963/naveksoft_logo?e=1764201600&v=beta&t=kGHD1Faiwj_3260HUHXIOlhLgmHSrvC2V_5e9T9Zo3U',
#          'expiresAt': 1764201600000,
#          'height': 200},
#         {'width': 100,
#          'fileIdentifyingUrlPathSegment': '100_100/company-logo_100_100/0/1633002358963/naveksoft_logo?e=1764201600&v=beta&t=GE0rOqa5EU7NzB77klQllx8g6yDx1XnkyBwUrNTFGxI',
#          'expiresAt': 1764201600000,
#          'height': 100},
#         {'width': 400,
# ...

# %%
url = "https://www.linkedin.com/jobs/view/4288878222"
job_id_epam = "4288878222"

job_epam = api.get_job(job_id_epam)

# %%
job_epam
# Out:
# {'dashEntityUrn': 'urn:li:fsd_jobPosting:4288878222',
#  'companyDetails': {'com.linkedin.voyager.deco.jobs.web.shared.WebCompactJobPostingCompany': {'companyResolutionResult': {'entityUrn': 'urn:li:fs_normalized_company:4972',
#     'name': 'EPAM Systems',
#     'logo': {'image': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 200,
#          'fileIdentifyingUrlPathSegment': '200_200/company-logo_200_200/0/1736349454702/epam_systems_logo?e=1764201600&v=beta&t=uHwAK1m8o2uGVpjnTHCNxUtoSHXDipipiQKrNQhvRvo',
#          'expiresAt': 1764201600000,
#          'height': 200},
#         {'width': 100,
#          'fileIdentifyingUrlPathSegment': '100_100/company-logo_100_100/0/1736349454702/epam_systems_logo?e=1764201600&v=beta&t=E_ssE75mZIgs3fWQfqJNofyZHySk8EPFXUKO8t4Pn4I',
#          'expiresAt': 1764201600000,
#          'height': 100},
#         {'width': 400,
# ...
